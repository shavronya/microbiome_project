# %%
#Import modules
from sqlalchemy import create_engine
import pandas as pd
from urllib.parse import quote_plus
from pandas import ExcelWriter

# %%
# Define the password
password = 'Password123#@!'

# Encode the password for the connection string
encoded_password = quote_plus(password)

# Create a MySQL database connection using SQLAlchemy
engine = create_engine(f'mysql://root:{encoded_password}@127.0.0.1/microbiome')

# %%
# Your SQL query
query1 = 'SELECT * FROM microbe'

# Reading data into a pandas DataFrame
microbe = pd.read_sql(query1, con=engine)

print(microbe)
# Out:
#      microbe_id    ncbi_id                   phylum            class  \
# 0             1     1678.0           Actinomycetota    Actinomycetes
# 1             2   572511.0                Bacillota       Clostridia
# 2             3    68337.0         Deferribacterota  Deferribacteres
# 3             4      841.0                Bacillota       Clostridia
# 4             5    28050.0                Bacillota       Clostridia
# ..          ...        ...                      ...              ...
# 701         706   340486.0             Bacteroidota      Bacteroidia
# 702         707   653385.0           Actinomycetota    Actinomycetes
# 703         708   423477.0                Bacillota    Negativicutes
# 704         709  1986146.0  Thermodesulfobacteriota    Desulfobulbia
# 705         710   327575.0             Bacteroidota   Flavobacteriia
#
#                  order              family            genus  \
# 0    Bifidobacteriales  Bifidobacteriaceae  Bifidobacterium
# ...

# %%
# Your SQL query
query8 = 'SELECT species, COUNT(*) FROM microbe GROUP BY species HAVING COUNT(*) > 1'

# Reading data into a pandas DataFrame
microbe = pd.read_sql(query8, con=engine)

print(microbe)
# Out:
#   species  COUNT(*)
# 0    None       268

# %%
query2 = 'SELECT * FROM host'

# Reading data into a pandas DataFrame
host = pd.read_sql(query2, con=engine)

print(host)
# Out:
#     host_id  host_type       species   strain  race geographic_location  \
# 0         1      Human  Homo sapiens     None  None           Indonesia
# 1         2      Human  Homo sapiens     None  None                  UK
# 2         3      Human  Homo sapiens     None  None                  UK
# 3         4  Non-human  Mus musculus  C57BL/6  None                 USA
# 4         5  Non-human  Mus musculus  C57BL/6  None                 USA
# ..      ...        ...           ...      ...   ...                 ...
# 76       77      Human  Homo sapiens     None  None             Germany
# 77       78      Human  Homo sapiens     None  None             Germany
# 78       79      Human  Homo sapiens     None  None                 USA
# 79       80      Human  Homo sapiens     None  None                 USA
# 80       81      Human  Homo sapiens     None  None                 USA
#
#    test_sample_size                                      control_group  \
# ...

# %%
query3 = 'SELECT * FROM `condition`'

# Reading data into a pandas DataFrame
condition = pd.read_sql(query3, con=engine)

print(condition)
# Out:
#     condition_id                            condition_type  \
# 0              1                         Colorectal cancer
# 1              2   Systemic inflammatory response syndrome
# 2              3                           Type 2 diabetes
# 3              4                      Diabetic retinopathy
# 4              5                  Hepatocellular Carcinoma
# 5              6                                   Obesity
# 6              7  Metabolic‐associated fatty liver disease
# 7              8  Human immunodeficiency virus-1 infection
# 8              9                           Crohn’s disease
# 9             10    Functional gastrointestinal disorders
# 10            11         Congenital heart disease followed
# 11            12                Esophageal adenocarcinoma
# 12            13                             Breast cancer
# 13            14                  Hidradenitis suppurativa
# 14            15                        Ulcerative colitis
# ...

# %%
query4 = 'SELECT * FROM method'

# Reading data into a pandas DataFrame
method = pd.read_sql(query4, con=engine)

print(method)
# Out:
#     method_id               method_type          platform
# 0           1         PCR-DGGE analysis            Biorad
# 1           2               16s RNA seq    Illumina MiSeq
# 2           3               16s RNA seq              None
# 3           4               16s RNA seq    Illumina HiSeq
# 4           5               16s RNA seq   GS-FLX Titanium
# 5           6               16s RNA seq               Ion
# 6           7               shotgun seq  Illumina NovaSeq
# 7           8                      qPCR     MX3000 system
# 8           9               shotgun seq            MGISEQ
# 9          10                   ITS seq   GS-FLX Titanium
# 10         11               shotgun seq    Illumina HiSeq
# 11         12                      qPCR         ABI PRISM
# 12         13                      FISH              None
# 13         14  microbiological analysis              None
# 14         15               shotgun seq               ABI

# %%
query5 = 'SELECT * FROM publication'

# Reading data into a pandas DataFrame
publication = pd.read_sql(query5, con=engine)

print(publication)
# Out:
#     publication_id           name       surname  year  \
# 0                1              F         Yusuf  2019
# 1                2            Tim         Sloan  2018
# 2                3        Ibrahim        Yusufu  2021
# 3                4     Taraprasad           Das  2021
# 4                5        Mélanie     Fouesnard  2021
# 5                6            Jay           Liu  2019
# 6                7         Xinyun           Qiu  2020
# 7                8             Ky           Cho  2021
# 8                9            Lan          Zhao  2021
# 9               10            Kai          Kang  2020
# 10              11         George      Saffouri  2019
# 11              12        Jeffrey       Salomon  2021
# 12              13          Alice     Zaramella  2023
# 13              14         Ruixin           Liu  2017
# 14              15     Alessandra          Riva  2017
# 15              16       Mohammad        Mouzan  2018
# ...

# %%
query6 = 'SELECT * FROM site'

# Reading data into a pandas DataFrame
site = pd.read_sql(query6, con=engine)

print(site)
# Out:
#    site_id           site_type
# 0        1               Feces
# 1        2  Intestinal mucosal
# 2        3       Breast tissue
# 3        4       Hair follicle
# 4        5               Blood
# 5        6     Dental calculus
# 6        7         Oral cavity
# 7        8              Plaque
# 8        9              Saliva

# %%
query7 = 'SELECT * FROM study'

# Reading data into a pandas DataFrame
study = pd.read_sql(query7, con=engine)

print(study)
# Out:
#       study_id  publication_id  host_id  microbe_id MAG  method_id  dysbiosis  \
# 0            1               1        1           1  no        1.0    Missing
# 1            2               2        2           1  no        2.0  Decreased
# 2            3               2        2          27  no        2.0  Increased
# 3            4               2        2          45  no        2.0  Increased
# 4            5               2        2          12  no        2.0  Decreased
# ...        ...             ...      ...         ...  ..        ...        ...
# 1362      1363              54       80         276  no       15.0  Decreased
# 1363      1364              54       80         277  no       15.0    Missing
# 1364      1365              54       80         677  no       15.0    Missing
# 1365      1366              54       81         394  no       15.0  Decreased
# 1366      1367              54       81         276  no       15.0  Decreased
#
# ...

# %%
excel_file_path = './microbiome.xlsx'  # Replace with the desired file path and name

with ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
    study.to_excel(writer, sheet_name='study', index=False)
    publication.to_excel(writer, sheet_name='publication', index=False)
    host.to_excel(writer, sheet_name='host', index=False)
    site.to_excel(writer, sheet_name='site', index=False)
    method.to_excel(writer, sheet_name='method', index=False)
    condition.to_excel(writer, sheet_name='condition', index=False)
    microbe.to_excel(writer, sheet_name='microbe', index=False)

# %%
df.to_sql(table_name, con=engine, if_exists='append', index=False)

# %%
engine.dispose()
